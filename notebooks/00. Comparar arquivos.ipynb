# %%
import os
from datetime import datetime
import pandas as pd
from tqdm import tqdm

tqdm.pandas()

# %%
def obter_informacoes_arquivos(pasta):
    informacoes_arquivos = []

    for pasta_atual, sub_pastas, arquivos in tqdm(os.walk(pasta)):
        for arquivo in arquivos:
            caminho_completo = os.path.join(pasta_atual, arquivo)

            try:
                info = os.stat(caminho_completo)
            except (PermissionError, FileNotFoundError) as e:
                # Lidar com exceções (pular o arquivo e imprimir uma mensagem, se desejar)
                print(f"Erro ao obter informações de {caminho_completo}: {e}")
                continue

            # Extrair informações desejadas
            caminho_arquivo = caminho_completo
            arquivo, tipo_arquivo = os.path.splitext(arquivo)
            autor = info.st_uid
            data_criacao = datetime.fromtimestamp(info.st_ctime).strftime("%d/%m/%Y %H:%M")
            tempo_acesso = datetime.fromtimestamp(info.st_atime).strftime("%d/%m/%Y %H:%M")
            tempo_modificacao = datetime.fromtimestamp(info.st_mtime).strftime("%d/%m/%Y %H:%M")
            tempo_mudanca = datetime.fromtimestamp(info.st_ctime).strftime("%d/%m/%Y %H:%M")
            tamanho_arquivo = info.st_size

            # Criar um dicionário com as informações
            informacao_arquivo = {
                'caminho': caminho_arquivo,
                'arquivo': arquivo,
                'tipo_arquivo': tipo_arquivo,
                'data_criacao': data_criacao,
                'tempo_acesso': tempo_acesso,
                'tempo_modificacao': tempo_modificacao,
                'tempo_mudanca': tempo_mudanca,
                'tamanho': tamanho_arquivo
            }

            # Adicionar à lista de informações
            informacoes_arquivos.append(informacao_arquivo)
    print(informacoes_arquivos)
    return informacoes_arquivos

# %%
def arquivo_mais_recente(pasta, tipo_arquivo=None, data="tempo_acesso"):
    arquivos = obter_informacoes_arquivos(pasta)
    df_arquivos = pd.DataFrame(arquivos)

    # Filtrar por tipo de arquivo apenas se tipo_arquivo não for None
    if tipo_arquivo is not None:
        filtro = df_arquivos['tipo_arquivo'].str.contains(tipo_arquivo, regex=True)
        df_arquivos = df_arquivos[filtro]

    # Ordenar por data
    df_arquivos = df_arquivos.sort_values(by=data)

    arquivo = df_arquivos[0]

    return df_arquivos

# %%
registros = obter_informacoes_arquivos('database\\projects\\10002-CESAN') #arquivo_mais_recente('database\list files')
df_registros = pd.DataFrame(registros)
df_registros['data_criacao'].unique()
# Out:
# 162it [00:00, 4423.19it/s]
# Erro ao obter informações de database\projects\10002-CESAN\02. VITÓRIA\01. LEITÃO DA SILVA\12. Projeto Estrutural\_OLD\R01-CAIXA CILINDRICAS\Fwd_ CESAN - Caixas com seção circular\CESAN_VALA 3  - FORMAS-REV.00 - Circular.dxf: [WinError 3] O sistema não pode encontrar o caminho especificado: 'database\\projects\\10002-CESAN\\02. VITÓRIA\\01. LEITÃO DA SILVA\\12. Projeto Estrutural\\_OLD\\R01-CAIXA CILINDRICAS\\Fwd_ CESAN - Caixas com seção circular\\CESAN_VALA 3  - FORMAS-REV.00 - Circular.dxf'
# [{'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\Cadastro_Drenagem_PMV_Av_Maruipe_Vitoria.dxf', 'arquivo': 'Cadastro_Drenagem_PMV_Av_Maruipe_Vitoria', 'tipo_arquivo': '.dxf', 'data_criacao': '21/10/2024 10:40', 'tempo_acesso': '21/10/2024 10:40', 'tempo_modificacao': '21/10/2024 10:40', 'tempo_mudanca': '21/10/2024 10:40', 'tamanho': 11036794}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\Mapa de Vila Velha2 (2) - Copia.dxf', 'arquivo': 'Mapa de Vila Velha2 (2) - Copia', 'tipo_arquivo': '.dxf', 'data_criacao': '21/10/2024 10:40', 'tempo_acesso': '21/10/2024 10:40', 'tempo_modificacao': '21/10/2024 10:40', 'tempo_mudanca': '21/10/2024 10:40', 'tamanho': 222585694}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\Mapa de Vila Velha2 (2).dxf.err', 'arquivo': 'Mapa de Vila Velha2 (2).dxf', 'tipo_arquivo': '.err', 'data_criacao': '21/10/2024 10:40', 'tempo_acesso': '21/10/2024 10:40', 'tempo_modificacao': '21/10/2024 10:40', 'tempo_mudanca': '21/10/2024 10:40', 'tamanho': 163}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\Planta Geral Municipio de Vila Velha.dxf', 'arquivo': 'Planta Geral Municipio de Vila Velha', 'tipo_arquivo': '.dxf', 'data_criacao': '21/10/2024 10:40', 'tempo_acesso': '21/10/2024 10:40', 'tempo_modificacao': '21/10/2024 10:40', 'tempo_mudanca': '21/10/2024 10:40', 'tamanho': 10661714}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\Planta Geral Municipio de Vitória.dxf', 'arquivo': 'Planta Geral Municipio de Vitória', 'tipo_arquivo': '.dxf', 'data_criacao': '21/10/2024 10:40', 'tempo_acesso': '21/10/2024 10:41', 'tempo_modificacao': '21/10/2024 10:41', 'tempo_mudanca': '21/10/2024 10:40', 'tamanho': 365465426}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\01. Vitória\\O-DVT_A.dxf', 'arquivo': 'O-DVT_A', 'tipo_arquivo': '.dxf', 'data_criacao': '22/10/2024 23:23', 'tempo_acesso': '22/10/2024 23:26', 'tempo_modificacao': '22/10/2024 23:23', 'tempo_mudanca': '22/10/2024 23:23', 'tamanho': 425426970}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\01. Vitória\\redes Vitória demanda Praia do Canto.dxf', 'arquivo': 'redes Vitória demanda Praia do Canto', 'tipo_arquivo': '.dxf', 'data_criacao': '21/10/2024 10:38', 'tempo_acesso': '21/10/2024 10:39', 'tempo_modificacao': '21/10/2024 10:38', 'tempo_mudanca': '21/10/2024 10:38', 'tamanho': 28756760}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\01. Vitória\\Vitória - Água.dxf', 'arquivo': 'Vitória - Água', 'tipo_arquivo': '.dxf', 'data_criacao': '21/10/2024 10:38', 'tempo_acesso': '21/10/2024 10:39', 'tempo_modificacao': '21/10/2024 10:38', 'tempo_mudanca': '21/10/2024 10:38', 'tamanho': 81901412}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\01. Vitória\\Vitória Operacional_Água.dxf', 'arquivo': 'Vitória Operacional_Água', 'tipo_arquivo': '.dxf', 'data_criacao': '21/10/2024 10:39', 'tempo_acesso': '21/10/2024 10:44', 'tempo_modificacao': '21/10/2024 10:39', 'tempo_mudanca': '21/10/2024 10:39', 'tamanho': 332310744}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\01. Vitória\\06. SERAFIM DERENZE\\VIT-REDE-SERAFIM DERENZE-R00.dxf', 'arquivo': 'VIT-REDE-SERAFIM DERENZE-R00', 'tipo_arquivo': '.dxf', 'data_criacao': '22/10/2024 23:22', 'tempo_acesso': '23/10/2024 03:19', 'tempo_modificacao': '22/10/2024 23:22', 'tempo_mudanca': '22/10/2024 23:22', 'tamanho': 425582142}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\01. Vitória\\06. SERAFIM DERENZE\\00. Planilhas\\VIT-REDE-SERAFIM DERENZE-R00.dxf', 'arquivo': 'VIT-REDE-SERAFIM DERENZE-R00', 'tipo_arquivo': '.dxf', 'data_criacao': '22/10/2024 23:21', 'tempo_acesso': '22/10/2024 23:25', 'tempo_modificacao': '22/10/2024 23:21', 'tempo_mudanca': '22/10/2024 23:21', 'tamanho': 427563622}, {'caminho': 'database\\projects\\10002-CESAN\\00. RECEBIDOS\\01. Vitória\\08. JOÃO DOS SANTOS FILHO\\JOÃO DOS SANTOS FILHO.dxf', 'arquivo': 'JOÃO DOS SANTOS FILHO', 'tipo_arquivo': '.d ...
# array(['21/10/2024 10:40', '22/10/2024 23:23', '21/10/2024 10:38',
#        '21/10/2024 10:39', '22/10/2024 23:22', '22/10/2024 23:21',
#        '21/10/2024 10:41', '23/10/2024 03:19', '21/10/2024 10:43',
#        '21/10/2024 10:42', '21/10/2024 10:44', '23/10/2024 02:34',
#        '21/10/2024 10:45', '21/10/2024 10:49', '21/10/2024 10:50',
#        '21/10/2024 10:51', '21/10/2024 10:52', '21/10/2024 10:53',
#        '21/10/2024 10:54', '21/10/2024 10:46', '21/10/2024 10:47',
#        '21/10/2024 10:48', '21/10/2024 11:01', '21/10/2024 10:55',
#        '21/10/2024 10:56', '21/10/2024 10:58', '21/10/2024 10:57',
#        '21/10/2024 10:59', '21/10/2024 11:00', '21/10/2024 11:03',
#        '21/10/2024 11:02', '21/10/2024 11:04', '21/10/2024 11:05',
#        '21/10/2024 11:06', '21/10/2024 11:07', '21/10/2024 11:08',
#        '21/10/2024 11:09', '21/10/2024 11:10', '21/10/2024 11:11',
#        '21/10/2024 11:12', '21/10/2024 11:28', '21/10/2024 11:13',
#        '21/10/2024 11:14', '21/10/2024 11:15', '21/10/2024 11:16',
#        '21/10/2024 11:17', '21/10/2024 11:18', '21/10/2024 11:19',
#        '21/10/2024 11:20', '21/10/2024 11:21', '21/10/2024 11:22',
#        '21/10/2024 11:23', '21/10/2024 11:24', '21/10/2024 11:25',
#        '21/10/2024 11:26', '21/10/2024 11:27', '21/10/2024 11:30',
#        '21/10/2024 11:29', '21/10/2024 11:31', '21/10/2024 11:32'],
#       dtype=object)
