# %%
import os
from datetime import datetime
import pandas as pd
from tqdm import tqdm

tqdm.pandas()

# %%
import re

def categoria_proj(nome_arquivo):
    # Define os padrões e as categorias correspondentes
    categorias = {
        "REDE": r"\bREDE\b",
        "PREF": r"\bPREF\b",
        "MAP": r"\bMAP\b",
        "TOP": r"\bTOP\b",
        "CAD": r"\bCAD\b",
        "SPT": r"\bSPT\b",
        "AS BUILT": r"\bAS BUILT\b",
        "RAMAL": r"\bRAMAL\b",
        "PLANO DE FURO": r"\bPF\b"
    }
    
    # Verifica qual padrão corresponde ao nome do arquivo
    for categoria, padrao in categorias.items():
        if re.search(padrao, nome_arquivo):
            return categoria
    
    # Retorna "Não definido" caso não encontre uma categoria
    return "Não definido"

# %%
def obter_informacoes_arquivos(pasta):
    informacoes_arquivos = []

    for pasta_atual, sub_pastas, arquivos in tqdm(os.walk(pasta)):
        for arquivo in arquivos:
            caminho_completo = os.path.join(pasta_atual, arquivo)

            try:
                info = os.stat(caminho_completo)
            except (PermissionError, FileNotFoundError) as e:
                # Lidar com exceções (pular o arquivo e imprimir uma mensagem, se desejar)
                print(f"Erro ao obter informações de {caminho_completo}: {e}")
                continue

            # Extrair informações desejadas
            caminho_arquivo = caminho_completo
            arquivo, tipo_arquivo = os.path.splitext(arquivo)
            autor = info.st_uid
            data_criacao = datetime.fromtimestamp(info.st_ctime).strftime("%d/%m/%Y %H:%M")
            tempo_acesso = datetime.fromtimestamp(info.st_atime).strftime("%d/%m/%Y %H:%M")
            tempo_modificacao = datetime.fromtimestamp(info.st_mtime).strftime("%d/%m/%Y %H:%M")
            tempo_mudanca = datetime.fromtimestamp(info.st_ctime).strftime("%d/%m/%Y %H:%M")
            tamanho_arquivo = info.st_size,
            tipo_proj = categoria_proj(arquivo)

            # Criar um dicionário com as informações
            informacao_arquivo = {
                'caminho': caminho_arquivo,
                'arquivo': arquivo,
                'tipo_arquivo': tipo_arquivo,
                'tipo_proj': tipo_proj,
                'data_criacao': data_criacao,
                'tempo_acesso': tempo_acesso,
                'tempo_modificacao': tempo_modificacao,
                'tempo_mudanca': tempo_mudanca,
                'tamanho': tamanho_arquivo
            }

            # Adicionar à lista de informações
            informacoes_arquivos.append(informacao_arquivo)
    print(informacoes_arquivos)
    return informacoes_arquivos

# %%
def criar_pasta_do_dia(caminho_base, nome):
    # Obtém a data atual
    data_atual = datetime.now()

    # Formata a data como YYYYMMDD
    data = data_atual.strftime("%Y-%m-%d")
    data_hora = data_atual.strftime("%Y-%m-%d_%H.%M.%S")

    # Constrói o caminho da pasta do dia
    caminho_pasta_do_dia = os.path.join(caminho_base, data)

    # Cria a pasta se ela não existir
    if not os.path.exists(caminho_pasta_do_dia):
        os.makedirs(caminho_pasta_do_dia)

    # Constrói o nome do arquivo com a data
    nome_arquivo = f'{caminho_pasta_do_dia}\{data_hora} - {nome}.csv'

    # Salva o DataFrame no arquivo
    informacoes_df.to_csv(nome_arquivo, encoding="utf-8")

    return informacoes_df.to_csv(nome_arquivo, encoding="utf-8")
# Out:
# <string>:17: SyntaxWarning: invalid escape sequence '\{'
# <>:17: SyntaxWarning: invalid escape sequence '\{'
# <string>:17: SyntaxWarning: invalid escape sequence '\{'
# <>:17: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\lucas.almeida\AppData\Local\Temp\ipykernel_3684\336270697.py:17: SyntaxWarning: invalid escape sequence '\{'
#   nome_arquivo = f'{caminho_pasta_do_dia}\{data_hora} - {nome}.csv'

# %%
caminho = ['database\\projects data', 'database\\projects\\10002-CESAN-25']
nome = ['Projects Data', 'Projects 10002-CENSAN 25']

Pastas = {
  'nome': nome,
  'caminho': caminho
}

Pastas_df = pd.DataFrame(Pastas)

for index, row in tqdm(Pastas_df.iterrows()):

  informacoes = obter_informacoes_arquivos(row['caminho'])

  informacoes_df = pd.DataFrame(informacoes)
  informacoes_df['tamanho'] = informacoes_df['tamanho'].apply(lambda x: x[0] if isinstance(x, tuple) else x)

  informacoes_df['tamanho_kb'] = round(informacoes_df['tamanho']/1024, 2)

  display(informacoes_df)

  informacoes_df = informacoes_df.sort_values(by='tipo_arquivo')
  print(informacoes_df['tipo_arquivo'].unique())

  nome = row['nome']
  caminho_pasta_do_dia = criar_pasta_do_dia('.\\database\\list data', nome)
# Out:
# 107it [00:00, 3255.57it/s]
# [{'caminho': 'database\\projects data\\10002-CESAN\\10002-CESAN.xlsx', 'arquivo': '10002-CESAN', 'tipo_arquivo': '.xlsx', 'tipo_proj': 'Não definido', 'data_criacao': '23/10/2024 03:51', 'tempo_acesso': '02/01/2025 15:42', 'tempo_modificacao': '02/01/2025 15:42', 'tempo_mudanca': '23/10/2024 03:51', 'tamanho': (10318,)}, {'caminho': 'database\\projects data\\10002-CESAN\\02. VITÓRIA\\VIT-REDE-VITÓRIA-R00.xlsx', 'arquivo': 'VIT-REDE-VITÓRIA-R00', 'tipo_arquivo': '.xlsx', 'tipo_proj': 'REDE', 'data_criacao': '25/10/2024 18:18', 'tempo_acesso': '03/11/2024 23:18', 'tempo_modificacao': '03/11/2024 10:19', 'tempo_mudanca': '25/10/2024 18:18', 'tamanho': (10370539,)}, {'caminho': 'database\\projects data\\10002-CESAN\\02. VITÓRIA\\01. LEITÃO DA SILVA\\VIT-REDE-AV. LEITÃO SILVA-R02.xlsx', 'arquivo': 'VIT-REDE-AV. LEITÃO SILVA-R02', 'tipo_arquivo': '.xlsx', 'tipo_proj': 'REDE', 'data_criacao': '23/10/2024 03:50', 'tempo_acesso': '03/11/2024 23:18', 'tempo_modificacao': '23/10/2024 06:19', 'tempo_mudanca': '23/10/2024 03:50', 'tamanho': (1748848,)}, {'caminho': 'database\\projects data\\10002-CESAN\\02. VITÓRIA\\01. LEITÃO DA SILVA\\02. Topografia\\VIT-TOP-2024-04-26 AV. LEITÃO DA SILVA.xlsx', 'arquivo': 'VIT-TOP-2024-04-26 AV. LEITÃO DA SILVA', 'tipo_arquivo': '.xlsx', 'tipo_proj': 'TOP', 'data_criacao': '13/11/2024 15:07', 'tempo_acesso': '13/11/2024 16:24', 'tempo_modificacao': '13/11/2024 16:24', 'tempo_mudanca': '13/11/2024 15:07', 'tamanho': (51202,)}, {'caminho': 'database\\projects data\\10002-CESAN\\02. VITÓRIA\\01. LEITÃO DA SILVA\\02. Topografia\\VIT-TOP-2024-04-30 SOND LEITÃO DA SILVA.xlsx', 'arquivo': 'VIT-TOP-2024-04-30 SOND LEITÃO DA SILVA', 'tipo_arquivo': '.xlsx', 'tipo_proj': 
# 3    database\projects data\10002-CESAN\02. VITÓRIA...
# 4    database\projects data\10002-CESAN\02. VITÓRIA...
# ..                                                 ...
# 183  database\projects data\10002-CESAN-25\03. VILA...
# 184  database\projects data\10002-CESAN-25\03. VILA...
# 185  database\projects data\10002-CESAN-25\03. VILA...
# 186  database\projects data\10002-CESAN-25\03. VILA...
# 187  database\projects data\10002-CESAN-25\04. GUAR...
#
#                                      arquivo tipo_arquivo     tipo_proj  \
# 0                                10002-CESAN        .xlsx  Não definido
# 1                       VIT-REDE-VITÓRIA-R00        .xlsx          REDE
# 2              VIT-REDE-AV. LEITÃO SILVA-R02        .xlsx          REDE
# 3     VIT-TOP-2024-04-26 AV. LEITÃO DA SILVA        .xlsx           TOP
# 4    VIT-TOP-2024-04-30 SOND LEITÃO DA SILVA        .xlsx           TOP
# ..                                       ...          ...           ...
# 183            2024-12-26 JM Vila Velha_REDE        .xlsx  Não definido
# 184            2024-12-26 NO Vila Velha_REDE        .xlsx  Não definido
# 185            2024-12-26 NS Vila Velha_REDE        .xlsx  Não definido
# 186    2024-12-26 Paraguassu Vila Velha_REDE        .xlsx  Não definido
# 187                   VIT-REDE-GUARAPARI-R04        .xlsx          REDE
#
#          data_criacao      tempo_acesso tempo_modificacao     tempo_mudanca  \
# 0    23/10/2024 03:51  02/01/2025 15:42  02/01/2025 15:42  23/10/2024 03:51
# 1    25/10/2024 18:18  03/11/2024 23:18  03/11/2024 10:19  25/10/2024 18:18
# 2    23/10/2024 03:50  03/11/2024 23:18  23/10/2024 06:19  23/10/2024 03:50
# 3    13/11/2024 15:07  13/11/2024 16:24  13/11/2024 16:24  13/11/2024 15:07
# 4    13/11/2024 15:07  13/11/2024 15:07  13/11/2024 15:07  13/11/2024 15:07
# ..                ...               ...               ...               ...
# 183  02/01/2025 15:32  02/01/2025 15:33  02/01/2025 15:32  02/01/2025 15:32
# 184  02/01/2025 15:32  02/01/2025 15:33  02/01/2025 15:32  02/01/2025 15:32
# 185  02/01/2025 15:32  02/01/2025 15:33  02/01/2025 15:32  02/01/2025 15:32
# 186  02/01/2025 15:32  02/01/2025 15:33  02/01/2025 15:32  02/01/2025 15:32
# 187  02/01/2025 15:36  02/01/2025 15:45  02/01/2025 15:42  02/01/2025 15:36
#
#       tamanho  tamanho_kb
# 0       10318       10.08
# 1    10370539    10127.48
# 2     1748848     1707.86
# 3       51202       50.00
# 4        7736        7.55
# ..        ...         ...
# 183     43773       42.75
# 184     14411       14.07
# 185     21286       20.79
# 186     13200       12.89
# 187  59065169    57680.83
#
# [188 rows x 10 columns]
# ['.xlsx']
# 109it [00:00, 2436.85it/s]
# [{'caminho': 'database\\projects\\10002-CESAN-25\\00. RECEBIDOS\\01. Vitória\\06. SERAFIM DERENZE\\VIT-REDE-SERAFIM DERENZE-R00.dxf', 'arquivo': 'VIT-REDE-SERAFIM DERENZE-R00', 'tipo_arquivo': '.dxf', 'tipo_proj': 'REDE', 'data_criacao': '02/01/2025 16:04', 'tempo_acesso': '02/01/2025 16:06', 'tempo_modific
': '02/01/2025 16:06', 'tempo_acesso': '02/01/2025 16:06', 'tempo_modificacao': '02/01/2025 16:06', 'tempo_mudanca': '02/01/2025 16:06', 'tamanho': (371432,)}, {'caminho': 'database\\projects\\10002-CESAN-25\\02. VITÓRIA\\01. LEITÃO DA SILVA\\02. Topografia\\VIT-TOP-2024-05-08 SOND AV. LEITÃO DA SILVA.dxf', 'arquivo': 'VIT-TOP-2024-05-08 SOND AV. LEITÃO DA SILVA', 'tipo_arquivo': '.dxf', 'tipo_proj': 'TOP', 'data_criacao': '02/01/2025 16:06', 'tempo_acesso': '02/01/2025 16:06', 'tempo_modificacao': '02/01/2025 16:06', 'tempo_mudanca': '02/01/2025 16:06', 'tamanho': (362104,)}, {'caminho': 'database\\projects\\10002-CESAN-25\\02. VITÓRIA\\01. LEITÃO DA SILVA\\02. Topografia\\VIT-TOP-2024-05-28 AV. LEITÃO DA SILVA.dxf', 'arquivo': 'VIT-TOP-2024-05-28 AV. LEITÃO DA SILVA', 'tipo_arquivo': '.dxf', 'tipo_proj': 'TOP', 'data_criacao': '02/01/2025 16:06', 'tempo_acesso': '02/01/2025 16:06', 'tempo_modificacao': '02/01/2025 16:06', 'tempo_mudanca': '02/01/2025 16:06', 'tamanho': (1146619,)}, {'caminho': 'database\\projects\\10002-CESAN-25\\02. VITÓRIA\\01. LEITÃO DA SILVA\\02. Topografia\\VIT-TOP-2024-07-06 AV. LEITÃO DA SILVA.dxf', 'arquivo': 'VIT-TOP-2024-07-06 AV. LEITÃO DA SILVA', 'tipo_arquivo': '.dxf', 'tipo_proj': 'TOP', 'data_criacao': '02/01/2025 16:06', 'tempo_acesso': '02/01/2025 16:06', 'tempo_modificacao':  ...
#                                                caminho  \
# 0    database\projects\10002-CESAN-25\00. RECEBIDOS...
# 1    database\projects\10002-CESAN-25\02. VITÓRIA\V...
# 2    database\projects\10002-CESAN-25\02. VITÓRIA\0...
# 3    database\projects\10002-CESAN-25\02. VITÓRIA\0...
# 4    database\projects\10002-CESAN-25\02. VITÓRIA\0...
# ..                                                 ...
# 176  database\projects\10002-CESAN-25\07. ARACRUZ\V...
# 177  database\projects\10002-CESAN-25\07. ARACRUZ\V...
# 178  database\projects\10002-CESAN-25\07. ARACRUZ\V...
# 179  database\projects\10002-CESAN-25\07. ARACRUZ\0...
# 180  database\projects\10002-CESAN-25\07. ARACRUZ\0...
#
#                                      arquivo tipo_arquivo tipo_proj  \
# 0               VIT-REDE-SERAFIM DERENZE-R00         .dxf      REDE
# 1                       VIT-REDE-VITÓRIA-R00         .dxf      REDE
# 2     VIT-TOP-2024-04-26 AV. LEITÃO DA SILVA         .dxf       TOP
# 3    VIT-TOP-2024-04-30 SOND LEITÃO DA SILVA         .dxf       TOP
# 4    VIT-TOP-2024-05-06 SOND LEITÃO DA SILVA         .dxf       TOP
# ..                                       ...          ...       ...
# 176                      VIT-TOP-ARACRUZ-R01         .dxf       TOP
# 177                      VIT-TOP-ARACRUZ-R02         .dxf       TOP
# 178                      VIT-TOP-ARACRUZ-R03         .dxf       TOP
# 179           VIT-TOP-2024-09-20-ARACRUZ-R01         .dxf       TOP
# 180                      VIT-TOP-ARACRUZ-R00         .dxf       TOP
#
#          data_criacao      tempo_acesso tempo_modificacao     tempo_mudanca  \
# 0    02/01/2025 16:04  02/01/2025 16:06  02/01/2025 16:06  02/01/2025 16:04
# 1    02/01/2025 16:16  02/01/2025 16:16  02/01/2025 16:16  02/01/2025 16:16
# 2    02/01/2025 16:06  02/01/2025 16:06  02/01/2025 16:06  02/01/2025 16:06
# 3    02/01/2025 16:06  02/01/2025 16:06  02/01/2025 16:06  02/01/2025 16:06
# 4    02/01/2025 16:06  02/01/2025 16:06  02/01/2025 16:06  02/01/2025 16:06
# ..                ...               ...               ...               ...
# 176  02/01/2025 16:48  03/01/2025 08:25  02/01/2025 16:48  02/01/2025 16:48
# 177  02/01/2025 16:48  03/01/2025 08:25  02/01/2025 16:48  02/01/2025 16:48
# 178  02/01/2025 16:48  03/01/2025 08:25  02/01/2025 16:48  02/01/2025 16:48
# 179  02/01/2025 16:48  03/01/2025 08:25  02/01/2025 16:48  02/01/2025 16:48
# 180  02/01/2025 16:48  03/01/2025 08:25  02/01/2025 16:48  02/01/2025 16:48
#
#        tamanho  tamanho_kb
# 0    425582142   415607.56
# 1     36020383    35176.16
# 2       510732      498.76
# 3       314786      307.41
# 4       359462      351.04
# ..         ...         ...
# 176   12078288    11795.20
# 177   12068988    11786.12
# 178   12101083    11817.46
# 179    4941108     4825.30
# 180    9205845     8990.08
#
# [181 rows x 10 columns]
# 2it [00:00, 16.58it/s]
# ['.dxf']

# %%
df = informacoes_df
df[['caminho', 'arquivo']]
# Out:
#                                                caminho  \
# 0    database\projects\10002-CESAN-25\00. RECEBIDOS...
# 115  database\projects\10002-CESAN-25\03. VILA VELH...
# 116  database\projects\10002-CESAN-25\03. VILA VELH...
# 117  database\projects\10002-CESAN-25\03. VILA VELH...
# 118  database\projects\10002-CESAN-25\03. VILA VELH...
# ..                                                 ...
# 62   database\projects\10002-CESAN-25\02. VITÓRIA\0...
# 63   database\projects\10002-CESAN-25\02. VITÓRIA\0...
# 64   database\projects\10002-CESAN-25\02. VITÓRIA\0...
# 66   database\projects\10002-CESAN-25\02. VITÓRIA\0...
# 180  database\projects\10002-CESAN-25\07. ARACRUZ\0...
#
#                                               arquivo
# 0                        VIT-REDE-SERAFIM DERENZE-R00
# 115                     VIT-TOP-2024-12-05-Vila Velha
# 116          VIT-TOP-2024-12-06-CARLOS LINDENBERG-R07
# 117          VIT-TOP-2024-12-06-JERONIMO MONTEIRO-R07
# 118  VIT-TOP-2024-12-12-CARLOS LINDENBERG-R07 ESTACAS
# ..                                                ...
# 62                VIT-REDE-000-CENTRO-R00 (ORÇAMENTO)
# 63                            VIT-REDE-000-CENTRO-R00
# 64                            VIT-REDE-000-CENTRO-R01
# 66                            VIT-REDE-000-CENTRO-R03
# 180                               VIT-TOP-ARACRUZ-R00
#
# [181 rows x 2 columns]

# %%
df.to_excel('tmp/projetos_origem.xlsx', index=False)
